# %% [markdown]
# # Monitoring IoT Sensor Data
# ## Data Subscriber Simulation
#
# This part of code simulates an IoT data subscriber that receives data sent out by a publisher via a MQTT broker. Note a subscriber doesn't work without a publisher or a broker.
#
# See IoT and sensor data.ipynb for more details about the publisher and broker.

# %% [markdown]
#  - The subscriber continuously receives the data. For each latest record r received, apply the 3NN classification to the last 5 records before r, and compare the classification result with the Outcome label in r.
#    - Repeat this for 1000 times, and report the number of correct classifications.

# %%
import paho.mqtt.client as mqtt
import time
import ast  # Import for safe dictionary conversion
from collections import deque  # Import for deque
import numpy as np  # Import numpy for array manipulation
from sklearn.neighbors import KNeighborsClassifier  # Import the KNN classifier

# %%
# Initialize a deque to store the last 6 records (5 previous + 1 current)
records = deque(maxlen=6)

# Define the on_connect function to handle connection events
def on_connect(client, userdata, flags, rc):
    print("Connected with result code", rc)
    # Subscribe to the "Records" topic
    client.subscribe("Records")

# Initialize a counter for correct classifications
correct_classifications = 0
total_iterations = 1000

# Define the on_message function to handle incoming messages
def on_message(client, userdata, msg):
    global records, correct_classifications, total_iterations
    # Decode the message payload
    raw_data = msg.payload.decode()
    print("Raw received data:", raw_data)  # Debugging step

    try:
        # Convert string representation of dictionary to actual dictionary
        data = ast.literal_eval(raw_data)

        # Extract expected features from the dictionary
        record = [
            data["Glucose"],
            data["BloodPressure"],
            data["Insulin"],
            data["Outcome"]
        ]

        # Store the record in the deque and process records as before
        records.append(record)

        # If we have at least 6 records, we can perform the 3NN classification
        if len(records) == 6:
            # Convert records to a numpy array
            records_array = np.array(records)
            # Split the features and the outcome
            X = records_array[:-1, :-1]  # Last 5 records, all features except the last column
            y = records_array[:-1, -1]   # Last 5 records, only the last column (Outcome)
            r = records_array[-1, :-1]   # Latest record, all features except the last column
            actual_outcome = records_array[-1, -1]  # Latest record, only the last column (Outcome)

            # Debugging steps to print the training data and new record
            print("Training Data (X):", X)
            print("Training Labels (y):", y)
            print("New Record (r):", r)

            # Create and train the 3NN classifier
            knn = KNeighborsClassifier(n_neighbors=3)
            knn.fit(X, y)
            # Predict the outcome for the latest record
            predicted_outcome = knn.predict([r])[0]

            # Print the predicted and actual outcomes
            print(f"Predicted Outcome: {predicted_outcome}, Actual Outcome: {actual_outcome}")
            print(total_iterations)

            # Check if the prediction is correct
            if predicted_outcome == actual_outcome:
                correct_classifications += 1

            # Decrement the total iterations counter
            total_iterations -= 1

         
    except Exception as e:
        print("Error:", e)

# Create MQTT client and define event handlers
mqttc = mqtt.Client()
mqttc.on_connect = on_connect
mqttc.on_message = on_message

# Connect to MQTT broker
mqttc.connect("mqtt.eclipseprojects.io", 1883, 60)
# Start the loop to process network traffic and dispatch callbacks
# Start the MQTT loop in a separate thread
mqttc.loop_start()

# Wait until total_iterations reaches zero
while total_iterations > 0:
    time.sleep(0.1)  # Small delay to prevent high CPU usage

# Stop and disconnect after 1000 iterations
mqttc.loop_stop()
mqttc.disconnect()

print(f"Final Result: {correct_classifications} correct classifications out of 1000.")
# Out:
# Connected with result code 0
# Raw received data: {'Glucose': 0.7989949748743719, 'BloodPressure': 0.5245901639344263, 'Insulin': 0.0, 'Outcome': 0}
# Raw received data: {'Glucose': 0.9045226130653267, 'BloodPressure': 0.5409836065573771, 'Insulin': 0.0, 'Outcome': 1}
# Raw received data: {'Glucose': 0.7336683417085427, 'BloodPressure': 0.45901639344262296, 'Insulin': 0.0, 'Outcome': 0}
# Raw received data: {'Glucose': 0.35678391959798994, 'BloodPressure': 0.5737704918032788, 'Insulin': 0.0, 'Outcome': 0}
# Raw received data: {'Glucose': 0.5175879396984925, 'BloodPressure': 0.5409836065573771, 'Insulin': 0.0, 'Outcome': 1}
# Raw received data: {'Glucose': 0.5276381909547738, 'BloodPressure': 0.0, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.79899497 0.52459016 0.        ]
#  [0.90452261 0.54098361 0.        ]
#  [0.73366834 0.45901639 0.        ]
#  [0.35678392 0.57377049 0.        ]
#  [0.51758794 0.54098361 0.        ]]
# Training Labels (y): [0. 1. 0. 0. 1.]
# New Record (r): [0.52763819 0.         0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 1000
# c:\Users\cbech\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\cbech\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")
# Raw received data: {'Glucose': 0.5175879396984925, 'BloodPressure': 0.6557377049180328, 'Insulin': 0.09692671394799054, 'Outcome': 0}
# Training Data (X): [[0.90452261 0.54098361 0.        ]
#  [0.73366834 0.45901639 0.        ]
#  [0.35678392 0.57377049 0.        ]
#  [0.51758794 0.54098361 0.        ]
#  [0.52763819 0.         0.        ]]
# Training Labels (y): [1. 0. 0. 1. 0.]
# New Record (r): [0.51758794 0.6557377  0.09692671]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 999
# Raw received data: {'Glucose': 0.507537688442211, 'BloodPressure': 0.4098360655737705, 'Insulin': 0.0425531914893617, 'Outcome': 0}
# Training Data (X): [[0.73366834 0.45901639 0.        ]
#  [0.35678392 0.57377049 0.        ]
#  [0.51758794 0.54098361 0.        ]
#  [0.52763819 0.         0.        ]
#  [0.51758794 0.6557377  0.09692671]]
# Training Labels (y): [0. 0. 1. 0. 0.]
# New Record (r): [0.50753769 0.40983607 0.04255319]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 998
# Raw received data: {'Glucose': 0.44221105527638194, 'BloodPressure': 0.5409836065573771, 'Insulin': 0.02718676122931442, 'Outcome': 0}
# Training Data (X): [[0.35678392 0.57377049 0.        ]
#  [0.51758794 0.54098361 0.        ]
#  [0.52763819 0.         0.        ]
#  [0.51758794 0.6557377  0.09692671]
#  [0.50753769 0.40983607 0.04255319]]
# Training Labels (y): [0. 1. 0. 0. 0.]
# New Record (r): [0.44221106 0.54098361 0.02718676]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 997
# Raw received data: {'Glucose': 0.8844221105527639, 'BloodPressure': 0.7377049180327869, 'Insulin': 0.3546099290780142, 'Outcome': 1}
# Training Data (X): [[0.51758794 0.54098361 0.        ]
#  [0.52763819 0.         0.        ]
#  [0.51758794 0.6557377  0.09692671]
#  [0.50753769 0.40983607 0.04255319]
#  [0.44221106 0.54098361 0.02718676]]
# Training Labels (y): [1. 0. 0. 0. 0.]
# New Record (r): [0.88442211 0.73770492 0.35460993]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 996
# Raw received data: {'Glucose': 0.7537688442211056, 'BloodPressure': 0.5409836065573771, 'Insulin': 0.40425531914893614, 'Outcome': 0}
# Training Data (X): [[0.52763819 0.         0.        ]
#  [0.51758794 0.6557377  0.09692671]
#  [0.50753769 0.40983607 0.04255319]
#  [0.44221106 0.54098361 0.02718676]
#  [0.88442211 0.73770492 0.35460993]]
# Training Labels (y): [0. 0. 0. 0. 1.]
# New Record (r): [0.75376884 0.54098361 0.40425532]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 995
# Raw received data: {'Glucose': 0.36683417085427134, 'BloodPressure': 0.4098360655737705, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.51758794 0.6557377  0.09692671]
#  [0.50753769 0.40983607 0.04255319]
#  [0.44221106 0.54098361 0.02718676]
#  [0.88442211 0.73770492 0.35460993]
#  [0.75376884 0.54098361 0.40425532]]
# Training Labels (y): [0. 0. 0. 1. 0.]
# New Record (r): [0.36683417 0.40983607 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 994
# Raw received data: {'Glucose': 0.9396984924623115, 'BloodPressure': 0.5573770491803279, 'Insulin': 0.359338061465721, 'Outcome': 1}
# Training Data (X): [[0.50753769 0.40983607 0.04255319]
#  [0.44221106 0.54098361 0.02718676]
#  [0.88442211 0.73770492 0.35460993]
#  [0.75376884 0.54098361 0.40425532]
#  [0.36683417 0.40983607 0.        ]]
# Training Labels (y): [0. 0. 1. 0. 0.]
# New Record (r): [0.93969849 0.55737705 0.35933806]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 993
# Raw received data: {'Glucose': 0.5025125628140703, 'BloodPressure': 0.7213114754098361, 'Insulin': 0.13002364066193853, 'Outcome': 0}
# Training Data (X): [[0.44221106 0.54098361 0.02718676]
#  [0.88442211 0.73770492 0.35460993]
#  [0.75376884 0.54098361 0.40425532]
#  [0.36683417 0.40983607 0.        ]
#  [0.93969849 0.55737705 0.35933806]]
# Training Labels (y): [0. 1. 0. 0. 1.]
# New Record (r): [0.50251256 0.72131148 0.13002364]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 992
# Raw received data: {'Glucose': 0.7336683417085427, 'BloodPressure': 0.6721311475409837, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.88442211 0.73770492 0.35460993]
#  [0.75376884 0.54098361 0.40425532]
#  [0.36683417 0.40983607 0.        ]
#  [0.93969849 0.55737705 0.35933806]
#  [0.50251256 0.72131148 0.13002364]]
# Training Labels (y): [1. 0. 0. 1. 0.]
# New Record (r): [0.73366834 0.67213115 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 991
# Raw received data: {'Glucose': 0.5276381909547738, 'BloodPressure': 0.5245901639344263, 'Insulin': 0.16784869976359337, 'Outcome': 0}
# Training Data (X): [[0.75376884 0.54098361 0.40425532]
#  [0.36683417 0.40983607 0.        ]
#  [0.93969849 0.55737705 0.35933806]
#  [0.50251256 0.72131148 0.13002364]
#  [0.73366834 0.67213115 0.        ]]
# Training Labels (y): [0. 0. 1. 0. 0.]
# New Record (r): [0.52763819 0.52459016 0.1678487 ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 990
# Raw received data: {'Glucose': 0.4221105527638191, 'BloodPressure': 0.0, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.36683417 0.40983607 0.        ]
#  [0.93969849 0.55737705 0.35933806]
#  [0.50251256 0.72131148 0.13002364]
#  [0.73366834 0.67213115 0.        ]
#  [0.52763819 0.52459016 0.1678487 ]]
# Training Labels (y): [0. 1. 0. 0. 0.]
# New Record (r): [0.42211055 0.         0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 989
# Raw received data: {'Glucose': 0.6683417085427136, 'BloodPressure': 0.5901639344262295, 'Insulin': 0.0, 'Outcome': 1}
# Training Data (X): [[0.93969849 0.55737705 0.35933806]
#  [0.50251256 0.72131148 0.13002364]
#  [0.73366834 0.67213115 0.        ]
#  [0.52763819 0.52459016 0.1678487 ]
#  [0.42211055 0.         0.        ]]
# Training Labels (y): [1. 0. 0. 0. 0.]
# New Record (r): [0.66834171 0.59016393 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 988
# Raw received data: {'Glucose': 0.22110552763819097, 'BloodPressure': 0.5081967213114754, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.50251256 0.72131148 0.13002364]
#  [0.73366834 0.67213115 0.        ]
#  [0.52763819 0.52459016 0.1678487 ]
#  [0.42211055 0.         0.        ]
#  [0.66834171 0.59016393 0.        ]]
# Training Labels (y): [0. 0. 0. 0. 1.]
# New Record (r): [0.22110553 0.50819672 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 987
# Raw received data: {'Glucose': 0.7085427135678392, 'BloodPressure': 0.4754098360655738, 'Insulin': 0.15130023640661938, 'Outcome': 0}
# Training Data (X): [[0.73366834 0.67213115 0.        ]
#  [0.52763819 0.52459016 0.1678487 ]
#  [0.42211055 0.         0.        ]
#  [0.66834171 0.59016393 0.        ]
#  [0.22110553 0.50819672 0.        ]]
# Training Labels (y): [0. 0. 0. 1. 0.]
# New Record (r): [0.70854271 0.47540984 0.15130024]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 986
# Raw received data: {'Glucose': 0.5728643216080402, 'BloodPressure': 0.5409836065573771, 'Insulin': 0.0, 'Outcome': 1}
# Training Data (X): [[0.52763819 0.52459016 0.1678487 ]
#  [0.42211055 0.         0.        ]
#  [0.66834171 0.59016393 0.        ]
#  [0.22110553 0.50819672 0.        ]
#  [0.70854271 0.47540984 0.15130024]]
# Training Labels (y): [0. 0. 1. 0. 0.]
# New Record (r): [0.57286432 0.54098361 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 985
# Raw received data: {'Glucose': 0.49748743718592964, 'BloodPressure': 0.6065573770491803, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.42211055 0.         0.        ]
#  [0.66834171 0.59016393 0.        ]
#  [0.22110553 0.50819672 0.        ]
#  [0.70854271 0.47540984 0.15130024]
#  [0.57286432 0.54098361 0.        ]]
# Training Labels (y): [0. 1. 0. 0. 1.]
# New Record (r): [0.49748744 0.60655738 0.        ]
# Predicted Outcome: 1.0, Actual Outcome: 0.0
# 984
# Raw received data: {'Glucose': 0.5477386934673367, 'BloodPressure': 0.7213114754098361, 'Insulin': 0.0, 'Outcome': 1}
# Training Data (X): [[0.66834171 0.59016393 0.        ]
#  [0.22110553 0.50819672 0.        ]
#  [0.70854271 0.47540984 0.15130024]
#  [0.57286432 0.54098361 0.        ]
#  [0.49748744 0.60655738 0.        ]]
# Training Labels (y): [1. 0. 0. 1. 0.]
# New Record (r): [0.54773869 0.72131148 0.        ]
# Predicted Outcome: 1.0, Actual Outcome: 1.0
# 983
# Raw received data: {'Glucose': 0.5477386934673367, 'BloodPressure': 0.7540983606557378, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.22110553 0.50819672 0.        ]
#  [0.70854271 0.47540984 0.15130024]
#  [0.57286432 0.54098361 0.        ]
#  [0.49748744 0.60655738 0.        ]
#  [0.54773869 0.72131148 0.        ]]
# Training Labels (y): [0. 0. 1. 0. 1.]
# New Record (r): [0.54773869 0.75409836 0.        ]
# Predicted Outcome: 1.0, Actual Outcome: 0.0
# 982
# Raw received data: {'Glucose': 0.47738693467336685, 'BloodPressure': 0.5409836065573771, 'Insulin': 0.044917257683215125, 'Outcome': 0}
# Training Data (X): [[0.70854271 0.47540984 0.15130024]
#  [0.57286432 0.54098361 0.        ]
#  [0.49748744 0.60655738 0.        ]
#  [0.54773869 0.72131148 0.        ]
#  [0.54773869 0.75409836 0.        ]]
# Training Labels (y): [0. 1. 0. 1. 0.]
# New Record (r): [0.47738693 0.54098361 0.04491726]
# Predicted Outcome: 1.0, Actual Outcome: 0.0
# 981
# Raw received data: {'Glucose': 0.7336683417085427, 'BloodPressure': 0.6967213114754098, 'Insulin': 0.1182033096926714, 'Outcome': 0}
# Training Data (X): [[0.57286432 0.54098361 0.        ]
#  [0.49748744 0.60655738 0.        ]
#  [0.54773869 0.72131148 0.        ]
#  [0.54773869 0.75409836 0.        ]
#  [0.47738693 0.54098361 0.04491726]]
# Training Labels (y): [1. 0. 1. 0. 0.]
# New Record (r): [0.73366834 0.69672131 0.11820331]
# Predicted Outcome: 1.0, Actual Outcome: 0.0
# 980
# Raw received data: {'Glucose': 0.5025125628140703, 'BloodPressure': 0.5409836065573771, 'Insulin': 0.10638297872340426, 'Outcome': 1}
# Training Data (X): [[0.49748744 0.60655738 0.        ]
#  [0.54773869 0.72131148 0.        ]
#  [0.54773869 0.75409836 0.        ]
#  [0.47738693 0.54098361 0.04491726]
#  [0.73366834 0.69672131 0.11820331]]
# Training Labels (y): [0. 1. 0. 0. 0.]
# New Record (r): [0.50251256 0.54098361 0.10638298]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 979
# Raw received data: {'Glucose': 0.6984924623115578, 'BloodPressure': 0.5245901639344263, 'Insulin': 0.16548463356973994, 'Outcome': 0}
# Training Data (X): [[0.54773869 0.72131148 0.        ]
#  [0.54773869 0.75409836 0.        ]
#  [0.47738693 0.54098361 0.04491726]
#  [0.73366834 0.69672131 0.11820331]
#  [0.50251256 0.54098361 0.10638298]]
# Training Labels (y): [1. 0. 0. 0. 1.]
# New Record (r): [0.69849246 0.52459016 0.16548463]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 978
# Raw received data: {'Glucose': 0.6331658291457286, 'BloodPressure': 0.7377049180327869, 'Insulin': 0.0, 'Outcome': 1}
# Training Data (X): [[0.54773869 0.75409836 0.        ]
#  [0.47738693 0.54098361 0.04491726]
#  [0.73366834 0.69672131 0.11820331]
#  [0.50251256 0.54098361 0.10638298]
#  [0.69849246 0.52459016 0.16548463]]
# Training Labels (y): [0. 0. 0. 1. 0.]
# New Record (r): [0.63316583 0.73770492 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 977
# Raw received data: {'Glucose': 0.6482412060301508, 'BloodPressure': 0.7049180327868853, 'Insulin': 0.3191489361702128, 'Outcome': 0}
# Training Data (X): [[0.47738693 0.54098361 0.04491726]
#  [0.73366834 0.69672131 0.11820331]
#  [0.50251256 0.54098361 0.10638298]
#  [0.69849246 0.52459016 0.16548463]
#  [0.63316583 0.73770492 0.        ]]
# Training Labels (y): [0. 0. 1. 0. 1.]
# New Record (r): [0.64824121 0.70491803 0.31914894]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 976
# Raw received data: {'Glucose': 0.3969849246231156, 'BloodPressure': 0.6147540983606558, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.73366834 0.69672131 0.11820331]
#  [0.50251256 0.54098361 0.10638298]
#  [0.69849246 0.52459016 0.16548463]
#  [0.63316583 0.73770492 0.        ]
#  [0.64824121 0.70491803 0.31914894]]
# Training Labels (y): [0. 1. 0. 1. 0.]
# New Record (r): [0.39698492 0.6147541  0.        ]
# Predicted Outcome: 1.0, Actual Outcome: 0.0
# 975
# Raw received data: {'Glucose': 0.0, 'BloodPressure': 0.39344262295081966, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.50251256 0.54098361 0.10638298]
#  [0.69849246 0.52459016 0.16548463]
#  [0.63316583 0.73770492 0.        ]
#  [0.64824121 0.70491803 0.31914894]
#  [0.39698492 0.6147541  0.        ]]
# Training Labels (y): [1. 0. 1. 0. 0.]
# New Record (r): [0.         0.39344262 0.        ]
# Predicted Outcome: 1.0, Actual Outcome: 0.0
# 974
# Raw received data: {'Glucose': 0.31155778894472363, 'BloodPressure': 0.639344262295082, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.69849246 0.52459016 0.16548463]
#  [0.63316583 0.73770492 0.        ]
#  [0.64824121 0.70491803 0.31914894]
#  [0.39698492 0.6147541  0.        ]
#  [0.         0.39344262 0.        ]]
# Training Labels (y): [0. 1. 0. 0. 0.]
# New Record (r): [0.31155779 0.63934426 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 973
# Raw received data: {'Glucose': 0.47738693467336685, 'BloodPressure': 0.5901639344262295, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.63316583 0.73770492 0.        ]
#  [0.64824121 0.70491803 0.31914894]
#  [0.39698492 0.6147541  0.        ]
#  [0.         0.39344262 0.        ]
#  [0.31155779 0.63934426 0.        ]]
# Training Labels (y): [1. 0. 0. 0. 0.]
# New Record (r): [0.47738693 0.59016393 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 972
# Raw received data: {'Glucose': 0.6582914572864321, 'BloodPressure': 0.0, 'Insulin': 0.0, 'Outcome': 1}
# Training Data (X): [[0.64824121 0.70491803 0.31914894]
#  [0.39698492 0.6147541  0.        ]
#  [0.         0.39344262 0.        ]
#  [0.31155779 0.63934426 0.        ]
#  [0.47738693 0.59016393 0.        ]]
# Training Labels (y): [0. 0. 0. 0. 0.]
# New Record (r): [0.65829146 0.         0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 971
# Raw received data: {'Glucose': 0.5628140703517588, 'BloodPressure': 0.5409836065573771, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.39698492 0.6147541  0.        ]
#  [0.         0.39344262 0.        ]
#  [0.31155779 0.63934426 0.        ]
#  [0.47738693 0.59016393 0.        ]
#  [0.65829146 0.         0.        ]]
# Training Labels (y): [0. 0. 0. 0. 1.]
# New Record (r): [0.56281407 0.54098361 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 970
# Raw received data: {'Glucose': 0.5678391959798995, 'BloodPressure': 0.36065573770491804, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.         0.39344262 0.        ]
#  [0.31155779 0.63934426 0.        ]
#  [0.47738693 0.59016393 0.        ]
#  [0.65829146 0.         0.        ]
#  [0.56281407 0.54098361 0.        ]]
# Training Labels (y): [0. 0. 0. 1. 0.]
# New Record (r): [0.5678392  0.36065574 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 969
# Raw received data: {'Glucose': 0.37185929648241206, 'BloodPressure': 0.0, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.31155779 0.63934426 0.        ]
#  [0.47738693 0.59016393 0.        ]
#  [0.65829146 0.         0.        ]
#  [0.56281407 0.54098361 0.        ]
#  [0.5678392  0.36065574 0.        ]]
# Training Labels (y): [0. 0. 1. 0. 0.]
# New Record (r): [0.3718593 0.        0.       ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 968
# Raw received data: {'Glucose': 0.4170854271356784, 'BloodPressure': 0.639344262295082, 'Insulin': 0.08392434988179669, 'Outcome': 0}
# Training Data (X): [[0.47738693 0.59016393 0.        ]
#  [0.65829146 0.         0.        ]
#  [0.56281407 0.54098361 0.        ]
#  [0.5678392  0.36065574 0.        ]
#  [0.3718593  0.         0.        ]]
# Training Labels (y): [0. 1. 0. 0. 0.]
# New Record (r): [0.41708543 0.63934426 0.08392435]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 967
# Raw received data: {'Glucose': 0.507537688442211, 'BloodPressure': 0.5327868852459017, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.65829146 0.         0.        ]
#  [0.56281407 0.54098361 0.        ]
#  [0.5678392  0.36065574 0.        ]
#  [0.3718593  0.         0.        ]
#  [0.41708543 0.63934426 0.08392435]]
# Training Labels (y): [1. 0. 0. 0. 0.]
# New Record (r): [0.50753769 0.53278689 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 966
# Raw received data: {'Glucose': 0.6884422110552764, 'BloodPressure': 0.8852459016393444, 'Insulin': 0.0, 'Outcome': 1}
# Training Data (X): [[0.56281407 0.54098361 0.        ]
#  [0.5678392  0.36065574 0.        ]
#  [0.3718593  0.         0.        ]
#  [0.41708543 0.63934426 0.08392435]
#  [0.50753769 0.53278689 0.        ]]
# Training Labels (y): [0. 0. 0. 0. 0.]
# New Record (r): [0.68844221 0.8852459  0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 965
# Raw received data: {'Glucose': 0.5527638190954774, 'BloodPressure': 0.6065573770491803, 'Insulin': 0.14775413711583923, 'Outcome': 0}
# Training Data (X): [[0.5678392  0.36065574 0.        ]
#  [0.3718593  0.         0.        ]
#  [0.41708543 0.63934426 0.08392435]
#  [0.50753769 0.53278689 0.        ]
#  [0.68844221 0.8852459  0.        ]]
# Training Labels (y): [0. 0. 0. 0. 1.]
# New Record (r): [0.55276382 0.60655738 0.14775414]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 964
# Raw received data: {'Glucose': 0.5326633165829145, 'BloodPressure': 0.5901639344262295, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.3718593  0.         0.        ]
#  [0.41708543 0.63934426 0.08392435]
#  [0.50753769 0.53278689 0.        ]
#  [0.68844221 0.8852459  0.        ]
#  [0.55276382 0.60655738 0.14775414]]
# Training Labels (y): [0. 0. 0. 1. 0.]
# New Record (r): [0.53266332 0.59016393 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 963
# Raw received data: {'Glucose': 0.5025125628140703, 'BloodPressure': 0.5573770491803279, 'Insulin': 0.08392434988179669, 'Outcome': 0}
# Training Data (X): [[0.41708543 0.63934426 0.08392435]
#  [0.50753769 0.53278689 0.        ]
#  [0.68844221 0.8852459  0.        ]
#  [0.55276382 0.60655738 0.14775414]
#  [0.53266332 0.59016393 0.        ]]
# Training Labels (y): [0. 0. 1. 0. 0.]
# New Record (r): [0.50251256 0.55737705 0.08392435]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 962
# Raw received data: {'Glucose': 0.6834170854271356, 'BloodPressure': 0.5737704918032788, 'Insulin': 0.13002364066193853, 'Outcome': 1}
# Training Data (X): [[0.50753769 0.53278689 0.        ]
#  [0.68844221 0.8852459  0.        ]
#  [0.55276382 0.60655738 0.14775414]
#  [0.53266332 0.59016393 0.        ]
#  [0.50251256 0.55737705 0.08392435]]
# Training Labels (y): [0. 1. 0. 0. 0.]
# New Record (r): [0.68341709 0.57377049 0.13002364]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 961
# Raw received data: {'Glucose': 0.5376884422110553, 'BloodPressure': 0.5573770491803279, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.68844221 0.8852459  0.        ]
#  [0.55276382 0.60655738 0.14775414]
#  [0.53266332 0.59016393 0.        ]
#  [0.50251256 0.55737705 0.08392435]
#  [0.68341709 0.57377049 0.13002364]]
# Training Labels (y): [1. 0. 0. 0. 1.]
# New Record (r): [0.53768844 0.55737705 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 960
# Raw received data: {'Glucose': 0.4020100502512563, 'BloodPressure': 0.45081967213114754, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.55276382 0.60655738 0.14775414]
#  [0.53266332 0.59016393 0.        ]
#  [0.50251256 0.55737705 0.08392435]
#  [0.68341709 0.57377049 0.13002364]
#  [0.53768844 0.55737705 0.        ]]
# Training Labels (y): [0. 0. 0. 1. 0.]
# New Record (r): [0.40201005 0.45081967 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 959
# Raw received data: {'Glucose': 0.6180904522613065, 'BloodPressure': 0.6557377049180328, 'Insulin': 0.20803782505910165, 'Outcome': 0}
# Training Data (X): [[0.53266332 0.59016393 0.        ]
#  [0.50251256 0.55737705 0.08392435]
#  [0.68341709 0.57377049 0.13002364]
#  [0.53768844 0.55737705 0.        ]
#  [0.40201005 0.45081967 0.        ]]
# Training Labels (y): [0. 0. 1. 0. 0.]
# New Record (r): [0.61809045 0.6557377  0.20803783]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 958
# Raw received data: {'Glucose': 0.40703517587939697, 'BloodPressure': 0.639344262295082, 'Insulin': 0.05673758865248227, 'Outcome': 0}
# Training Data (X): [[0.50251256 0.55737705 0.08392435]
#  [0.68341709 0.57377049 0.13002364]
#  [0.53768844 0.55737705 0.        ]
#  [0.40201005 0.45081967 0.        ]
#  [0.61809045 0.6557377  0.20803783]]
# Training Labels (y): [0. 1. 0. 0. 0.]
# New Record (r): [0.40703518 0.63934426 0.05673759]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 957
# Raw received data: {'Glucose': 0.6733668341708543, 'BloodPressure': 0.5901639344262295, 'Insulin': 0.0, 'Outcome': 1}
# Training Data (X): [[0.68341709 0.57377049 0.13002364]
#  [0.53768844 0.55737705 0.        ]
#  [0.40201005 0.45081967 0.        ]
#  [0.61809045 0.6557377  0.20803783]
#  [0.40703518 0.63934426 0.05673759]]
# Training Labels (y): [1. 0. 0. 0. 0.]
# New Record (r): [0.67336683 0.59016393 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 956
# Raw received data: {'Glucose': 0.7135678391959799, 'BloodPressure': 0.6721311475409837, 'Insulin': 0.07565011820330969, 'Outcome': 0}
# Training Data (X): [[0.53768844 0.55737705 0.        ]
#  [0.40201005 0.45081967 0.        ]
#  [0.61809045 0.6557377  0.20803783]
#  [0.40703518 0.63934426 0.05673759]
#  [0.67336683 0.59016393 0.        ]]
# Training Labels (y): [0. 0. 0. 0. 1.]
# New Record (r): [0.71356784 0.67213115 0.07565012]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 955
# Raw received data: {'Glucose': 0.7236180904522613, 'BloodPressure': 0.5901639344262295, 'Insulin': 0.2695035460992908, 'Outcome': 0}
# Training Data (X): [[0.40201005 0.45081967 0.        ]
#  [0.61809045 0.6557377  0.20803783]
#  [0.40703518 0.63934426 0.05673759]
#  [0.67336683 0.59016393 0.        ]
#  [0.71356784 0.67213115 0.07565012]]
# Training Labels (y): [0. 0. 0. 1. 0.]
# New Record (r): [0.72361809 0.59016393 0.26950355]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 954
# Raw received data: {'Glucose': 0.4623115577889447, 'BloodPressure': 0.5081967213114754, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.61809045 0.6557377  0.20803783]
#  [0.40703518 0.63934426 0.05673759]
#  [0.67336683 0.59016393 0.        ]
#  [0.71356784 0.67213115 0.07565012]
#  [0.72361809 0.59016393 0.26950355]]
# Training Labels (y): [0. 0. 1. 0. 0.]
# New Record (r): [0.46231156 0.50819672 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 953
# Raw received data: {'Glucose': 0.35678391959798994, 'BloodPressure': 0.39344262295081966, 'Insulin': 0.08983451536643025, 'Outcome': 0}
# Training Data (X): [[0.40703518 0.63934426 0.05673759]
#  [0.67336683 0.59016393 0.        ]
#  [0.71356784 0.67213115 0.07565012]
#  [0.72361809 0.59016393 0.26950355]
#  [0.46231156 0.50819672 0.        ]]
# Training Labels (y): [0. 1. 0. 0. 0.]
# New Record (r): [0.35678392 0.39344262 0.08983452]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 952
# Raw received data: {'Glucose': 0.46733668341708545, 'BloodPressure': 0.4098360655737705, 'Insulin': 0.07565011820330969, 'Outcome': 0}
# Training Data (X): [[0.67336683 0.59016393 0.        ]
#  [0.71356784 0.67213115 0.07565012]
#  [0.72361809 0.59016393 0.26950355]
#  [0.46231156 0.50819672 0.        ]
#  [0.35678392 0.39344262 0.08983452]]
# Training Labels (y): [1. 0. 0. 0. 0.]
# New Record (r): [0.46733668 0.40983607 0.07565012]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 951
# Raw received data: {'Glucose': 0.6130653266331658, 'BloodPressure': 0.7377049180327869, 'Insulin': 0.26004728132387706, 'Outcome': 1}
# Training Data (X): [[0.71356784 0.67213115 0.07565012]
#  [0.72361809 0.59016393 0.26950355]
#  [0.46231156 0.50819672 0.        ]
#  [0.35678392 0.39344262 0.08983452]
#  [0.46733668 0.40983607 0.07565012]]
# Training Labels (y): [0. 0. 0. 0. 0.]
# New Record (r): [0.61306533 0.73770492 0.26004728]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 950
# Raw received data: {'Glucose': 0.8190954773869347, 'BloodPressure': 0.5901639344262295, 'Insulin': 0.0, 'Outcome': 1}
# Training Data (X): [[0.72361809 0.59016393 0.26950355]
#  [0.46231156 0.50819672 0.        ]
#  [0.35678392 0.39344262 0.08983452]
#  [0.46733668 0.40983607 0.07565012]
#  [0.61306533 0.73770492 0.26004728]]
# Training Labels (y): [0. 0. 0. 0. 1.]
# New Record (r): [0.81909548 0.59016393 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 949
# Raw received data: {'Glucose': 0.7587939698492463, 'BloodPressure': 0.49180327868852464, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.46231156 0.50819672 0.        ]
#  [0.35678392 0.39344262 0.08983452]
#  [0.46733668 0.40983607 0.07565012]
#  [0.61306533 0.73770492 0.26004728]
#  [0.81909548 0.59016393 0.        ]]
# Training Labels (y): [0. 0. 0. 1. 1.]
# New Record (r): [0.75879397 0.49180328 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 948
# Raw received data: {'Glucose': 0.628140703517588, 'BloodPressure': 0.7868852459016393, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.35678392 0.39344262 0.08983452]
#  [0.46733668 0.40983607 0.07565012]
#  [0.61306533 0.73770492 0.26004728]
#  [0.81909548 0.59016393 0.        ]
#  [0.75879397 0.49180328 0.        ]]
# Training Labels (y): [0. 0. 1. 1. 0.]
# New Record (r): [0.6281407  0.78688525 0.        ]
# Predicted Outcome: 1.0, Actual Outcome: 0.0
# 947
# Raw received data: {'Glucose': 0.40703517587939697, 'BloodPressure': 0.5901639344262295, 'Insulin': 0.04728132387706856, 'Outcome': 0}
# Training Data (X): [[0.46733668 0.40983607 0.07565012]
#  [0.61306533 0.73770492 0.26004728]
#  [0.81909548 0.59016393 0.        ]
#  [0.75879397 0.49180328 0.        ]
#  [0.6281407  0.78688525 0.        ]]
# Training Labels (y): [0. 1. 1. 0. 0.]
# New Record (r): [0.40703518 0.59016393 0.04728132]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 946
# Raw received data: {'Glucose': 0.4271356783919598, 'BloodPressure': 0.5327868852459017, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.61306533 0.73770492 0.26004728]
#  [0.81909548 0.59016393 0.        ]
#  [0.75879397 0.49180328 0.        ]
#  [0.6281407  0.78688525 0.        ]
#  [0.40703518 0.59016393 0.04728132]]
# Training Labels (y): [1. 1. 0. 0. 0.]
# New Record (r): [0.42713568 0.53278689 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 945
# Raw received data: {'Glucose': 0.6331658291457286, 'BloodPressure': 0.45901639344262296, 'Insulin': 0.1796690307328605, 'Outcome': 0}
# Training Data (X): [[0.81909548 0.59016393 0.        ]
#  [0.75879397 0.49180328 0.        ]
#  [0.6281407  0.78688525 0.        ]
#  [0.40703518 0.59016393 0.04728132]
#  [0.42713568 0.53278689 0.        ]]
# Training Labels (y): [1. 0. 0. 0. 0.]
# New Record (r): [0.63316583 0.45901639 0.17966903]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 944
# Raw received data: {'Glucose': 0.4824120603015075, 'BloodPressure': 1.0, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.75879397 0.49180328 0.        ]
#  [0.6281407  0.78688525 0.        ]
#  [0.40703518 0.59016393 0.04728132]
#  [0.42713568 0.53278689 0.        ]
#  [0.63316583 0.45901639 0.17966903]]
# Training Labels (y): [0. 0. 0. 0. 0.]
# New Record (r): [0.48241206 1.         0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 943
# Raw received data: {'Glucose': 0.7236180904522613, 'BloodPressure': 0.4754098360655738, 'Insulin': 0.16548463356973994, 'Outcome': 0}
# Training Data (X): [[0.6281407  0.78688525 0.        ]
#  [0.40703518 0.59016393 0.04728132]
#  [0.42713568 0.53278689 0.        ]
#  [0.63316583 0.45901639 0.17966903]
#  [0.48241206 1.         0.        ]]
# Training Labels (y): [0. 0. 0. 0. 0.]
# New Record (r): [0.72361809 0.47540984 0.16548463]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 942
# Raw received data: {'Glucose': 0.4170854271356784, 'BloodPressure': 0.4754098360655738, 'Insulin': 0.02127659574468085, 'Outcome': 0}
# Training Data (X): [[0.40703518 0.59016393 0.04728132]
#  [0.42713568 0.53278689 0.        ]
#  [0.63316583 0.45901639 0.17966903]
#  [0.48241206 1.         0.        ]
#  [0.72361809 0.47540984 0.16548463]]
# Training Labels (y): [0. 0. 0. 0. 0.]
# New Record (r): [0.41708543 0.47540984 0.0212766 ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 941
# Raw received data: {'Glucose': 0.47738693467336685, 'BloodPressure': 0.6967213114754098, 'Insulin': 0.0425531914893617, 'Outcome': 1}
# Training Data (X): [[0.42713568 0.53278689 0.        ]
#  [0.63316583 0.45901639 0.17966903]
#  [0.48241206 1.         0.        ]
#  [0.72361809 0.47540984 0.16548463]
#  [0.41708543 0.47540984 0.0212766 ]]
# Training Labels (y): [0. 0. 0. 0. 0.]
# New Record (r): [0.47738693 0.69672131 0.04255319]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 940
# Raw received data: {'Glucose': 0.8592964824120604, 'BloodPressure': 0.5901639344262295, 'Insulin': 0.1595744680851064, 'Outcome': 1}
# Training Data (X): [[0.63316583 0.45901639 0.17966903]
#  [0.48241206 1.         0.        ]
#  [0.72361809 0.47540984 0.16548463]
#  [0.41708543 0.47540984 0.0212766 ]
#  [0.47738693 0.69672131 0.04255319]]
# Training Labels (y): [0. 0. 0. 0. 1.]
# New Record (r): [0.85929648 0.59016393 0.15957447]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 939
# Raw received data: {'Glucose': 0.7788944723618091, 'BloodPressure': 0.5081967213114754, 'Insulin': 0.5851063829787234, 'Outcome': 1}
# Training Data (X): [[0.48241206 1.         0.        ]
#  [0.72361809 0.47540984 0.16548463]
#  [0.41708543 0.47540984 0.0212766 ]
#  [0.47738693 0.69672131 0.04255319]
#  [0.85929648 0.59016393 0.15957447]]
# Training Labels (y): [0. 0. 0. 1. 1.]
# New Record (r): [0.77889447 0.50819672 0.58510638]
# Predicted Outcome: 1.0, Actual Outcome: 1.0
# 938
# Raw received data: {'Glucose': 0.4472361809045226, 'BloodPressure': 0.6229508196721312, 'Insulin': 0.04373522458628842, 'Outcome': 0}
# Training Data (X): [[0.72361809 0.47540984 0.16548463]
#  [0.41708543 0.47540984 0.0212766 ]
#  [0.47738693 0.69672131 0.04255319]
#  [0.85929648 0.59016393 0.15957447]
#  [0.77889447 0.50819672 0.58510638]]
# Training Labels (y): [0. 0. 1. 1. 1.]
# New Record (r): [0.44723618 0.62295082 0.04373522]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 937
# Raw received data: {'Glucose': 0.38190954773869346, 'BloodPressure': 0.5081967213114754, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.41708543 0.47540984 0.0212766 ]
#  [0.47738693 0.69672131 0.04255319]
#  [0.85929648 0.59016393 0.15957447]
#  [0.77889447 0.50819672 0.58510638]
#  [0.44723618 0.62295082 0.04373522]]
# Training Labels (y): [0. 1. 1. 1. 0.]
# New Record (r): [0.38190955 0.50819672 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 936
# Raw received data: {'Glucose': 0.8040201005025126, 'BloodPressure': 0.4426229508196722, 'Insulin': 0.20685579196217493, 'Outcome': 1}
# Training Data (X): [[0.47738693 0.69672131 0.04255319]
#  [0.85929648 0.59016393 0.15957447]
#  [0.77889447 0.50819672 0.58510638]
#  [0.44723618 0.62295082 0.04373522]
#  [0.38190955 0.50819672 0.        ]]
# Training Labels (y): [1. 1. 1. 0. 0.]
# New Record (r): [0.8040201  0.44262295 0.20685579]
# Predicted Outcome: 1.0, Actual Outcome: 1.0
# 935
# Raw received data: {'Glucose': 0.7336683417085427, 'BloodPressure': 0.7540983606557378, 'Insulin': 0.0, 'Outcome': 1}
# Training Data (X): [[0.85929648 0.59016393 0.15957447]
#  [0.77889447 0.50819672 0.58510638]
#  [0.44723618 0.62295082 0.04373522]
#  [0.38190955 0.50819672 0.        ]
#  [0.8040201  0.44262295 0.20685579]]
# Training Labels (y): [1. 1. 0. 0. 1.]
# New Record (r): [0.73366834 0.75409836 0.        ]
# Predicted Outcome: 1.0, Actual Outcome: 1.0
# 934
# Raw received data: {'Glucose': 0.6231155778894473, 'BloodPressure': 0.6065573770491803, 'Insulin': 0.0, 'Outcome': 1}
# Training Data (X): [[0.77889447 0.50819672 0.58510638]
#  [0.44723618 0.62295082 0.04373522]
#  [0.38190955 0.50819672 0.        ]
#  [0.8040201  0.44262295 0.20685579]
#  [0.73366834 0.75409836 0.        ]]
# Training Labels (y): [1. 0. 0. 1. 1.]
# New Record (r): [0.62311558 0.60655738 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 933
# Raw received data: {'Glucose': 0.3919597989949749, 'BloodPressure': 0.39344262295081966, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.44723618 0.62295082 0.04373522]
#  [0.38190955 0.50819672 0.        ]
#  [0.8040201  0.44262295 0.20685579]
#  [0.73366834 0.75409836 0.        ]
#  [0.62311558 0.60655738 0.        ]]
# Training Labels (y): [0. 0. 1. 1. 1.]
# New Record (r): [0.3919598  0.39344262 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 932
# Raw received data: {'Glucose': 0.48743718592964824, 'BloodPressure': 0.49180327868852464, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.38190955 0.50819672 0.        ]
#  [0.8040201  0.44262295 0.20685579]
#  [0.73366834 0.75409836 0.        ]
#  [0.62311558 0.60655738 0.        ]
#  [0.3919598  0.39344262 0.        ]]
# Training Labels (y): [0. 1. 1. 1. 0.]
# New Record (r): [0.48743719 0.49180328 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 931
# Raw received data: {'Glucose': 0.49748743718592964, 'BloodPressure': 0.6229508196721312, 'Insulin': 0.06028368794326241, 'Outcome': 0}
# Training Data (X): [[0.8040201  0.44262295 0.20685579]
#  [0.73366834 0.75409836 0.        ]
#  [0.62311558 0.60655738 0.        ]
#  [0.3919598  0.39344262 0.        ]
#  [0.48743719 0.49180328 0.        ]]
# Training Labels (y): [1. 1. 1. 0. 0.]
# New Record (r): [0.49748744 0.62295082 0.06028369]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 930
# Raw received data: {'Glucose': 0.8140703517587939, 'BloodPressure': 0.6229508196721312, 'Insulin': 0.1182033096926714, 'Outcome': 1}
# Training Data (X): [[0.73366834 0.75409836 0.        ]
#  [0.62311558 0.60655738 0.        ]
#  [0.3919598  0.39344262 0.        ]
#  [0.48743719 0.49180328 0.        ]
#  [0.49748744 0.62295082 0.06028369]]
# Training Labels (y): [1. 1. 0. 0. 0.]
# New Record (r): [0.81407035 0.62295082 0.11820331]
# Predicted Outcome: 1.0, Actual Outcome: 1.0
# 929
# Raw received data: {'Glucose': 0.5577889447236181, 'BloodPressure': 0.5245901639344263, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.62311558 0.60655738 0.        ]
#  [0.3919598  0.39344262 0.        ]
#  [0.48743719 0.49180328 0.        ]
#  [0.49748744 0.62295082 0.06028369]
#  [0.81407035 0.62295082 0.11820331]]
# Training Labels (y): [1. 0. 0. 0. 1.]
# New Record (r): [0.55778894 0.52459016 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 928
# Raw received data: {'Glucose': 0.5376884422110553, 'BloodPressure': 0.6065573770491803, 'Insulin': 0.1182033096926714, 'Outcome': 0}
# Training Data (X): [[0.3919598  0.39344262 0.        ]
#  [0.48743719 0.49180328 0.        ]
#  [0.49748744 0.62295082 0.06028369]
#  [0.81407035 0.62295082 0.11820331]
#  [0.55778894 0.52459016 0.        ]]
# Training Labels (y): [0. 0. 0. 1. 0.]
# New Record (r): [0.53768844 0.60655738 0.11820331]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 927
# Raw received data: {'Glucose': 0.6633165829145728, 'BloodPressure': 0.6557377049180328, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.48743719 0.49180328 0.        ]
#  [0.49748744 0.62295082 0.06028369]
#  [0.81407035 0.62295082 0.11820331]
#  [0.55778894 0.52459016 0.        ]
#  [0.53768844 0.60655738 0.11820331]]
# Training Labels (y): [0. 0. 1. 0. 0.]
# New Record (r): [0.66331658 0.6557377  0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 926
# Raw received data: {'Glucose': 0.5678391959798995, 'BloodPressure': 0.6229508196721312, 'Insulin': 0.0, 'Outcome': 1}
# Training Data (X): [[0.49748744 0.62295082 0.06028369]
#  [0.81407035 0.62295082 0.11820331]
#  [0.55778894 0.52459016 0.        ]
#  [0.53768844 0.60655738 0.11820331]
#  [0.66331658 0.6557377  0.        ]]
# Training Labels (y): [0. 1. 0. 0. 0.]
# New Record (r): [0.5678392  0.62295082 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 925
# Raw received data: {'Glucose': 0.44221105527638194, 'BloodPressure': 0.24590163934426232, 'Insulin': 0.11702127659574468, 'Outcome': 1}
# Training Data (X): [[0.81407035 0.62295082 0.11820331]
#  [0.55778894 0.52459016 0.        ]
#  [0.53768844 0.60655738 0.11820331]
#  [0.66331658 0.6557377  0.        ]
#  [0.5678392  0.62295082 0.        ]]
# Training Labels (y): [1. 0. 0. 0. 1.]
# New Record (r): [0.44221106 0.24590164 0.11702128]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 924
# Raw received data: {'Glucose': 0.6030150753768845, 'BloodPressure': 0.5737704918032788, 'Insulin': 0.1595744680851064, 'Outcome': 0}
# Training Data (X): [[0.55778894 0.52459016 0.        ]
#  [0.53768844 0.60655738 0.11820331]
#  [0.66331658 0.6557377  0.        ]
#  [0.5678392  0.62295082 0.        ]
#  [0.44221106 0.24590164 0.11702128]]
# Training Labels (y): [0. 0. 0. 1. 1.]
# New Record (r): [0.60301508 0.57377049 0.15957447]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 923
# Raw received data: {'Glucose': 0.592964824120603, 'BloodPressure': 0.4754098360655738, 'Insulin': 0.1111111111111111, 'Outcome': 0}
# Training Data (X): [[0.53768844 0.60655738 0.11820331]
#  [0.66331658 0.6557377  0.        ]
#  [0.5678392  0.62295082 0.        ]
#  [0.44221106 0.24590164 0.11702128]
#  [0.60301508 0.57377049 0.15957447]]
# Training Labels (y): [0. 0. 1. 1. 0.]
# New Record (r): [0.59296482 0.47540984 0.11111111]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 922
# Raw received data: {'Glucose': 0.5879396984924623, 'BloodPressure': 0.7213114754098361, 'Insulin': 0.17139479905437352, 'Outcome': 1}
# Training Data (X): [[0.66331658 0.6557377  0.        ]
#  [0.5678392  0.62295082 0.        ]
#  [0.44221106 0.24590164 0.11702128]
#  [0.60301508 0.57377049 0.15957447]
#  [0.59296482 0.47540984 0.11111111]]
# Training Labels (y): [0. 1. 1. 0. 0.]
# New Record (r): [0.5879397  0.72131148 0.1713948 ]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 921
# Raw received data: {'Glucose': 0.5276381909547738, 'BloodPressure': 0.6885245901639344, 'Insulin': 0.0, 'Outcome': 1}
# Training Data (X): [[0.5678392  0.62295082 0.        ]
#  [0.44221106 0.24590164 0.11702128]
#  [0.60301508 0.57377049 0.15957447]
#  [0.59296482 0.47540984 0.11111111]
#  [0.5879397  0.72131148 0.1713948 ]]
# Training Labels (y): [1. 1. 0. 0. 1.]
# New Record (r): [0.52763819 0.68852459 0.        ]
# Predicted Outcome: 1.0, Actual Outcome: 1.0
# 920
# Raw received data: {'Glucose': 0.8693467336683417, 'BloodPressure': 0.5737704918032788, 'Insulin': 0.19858156028368795, 'Outcome': 1}
# Training Data (X): [[0.44221106 0.24590164 0.11702128]
#  [0.60301508 0.57377049 0.15957447]
#  [0.59296482 0.47540984 0.11111111]
#  [0.5879397  0.72131148 0.1713948 ]
#  [0.52763819 0.68852459 0.        ]]
# Training Labels (y): [1. 0. 0. 1. 1.]
# New Record (r): [0.86934673 0.57377049 0.19858156]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 919
# Raw received data: {'Glucose': 0.6130653266331658, 'BloodPressure': 0.45901639344262296, 'Insulin': 0.0, 'Outcome': 1}
# Training Data (X): [[0.60301508 0.57377049 0.15957447]
#  [0.59296482 0.47540984 0.11111111]
#  [0.5879397  0.72131148 0.1713948 ]
#  [0.52763819 0.68852459 0.        ]
#  [0.86934673 0.57377049 0.19858156]]
# Training Labels (y): [0. 0. 1. 1. 1.]
# New Record (r): [0.61306533 0.45901639 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 918
# Raw received data: {'Glucose': 0.8542713567839196, 'BloodPressure': 0.5245901639344263, 'Insulin': 0.26595744680851063, 'Outcome': 1}
# Training Data (X): [[0.59296482 0.47540984 0.11111111]
#  [0.5879397  0.72131148 0.1713948 ]
#  [0.52763819 0.68852459 0.        ]
#  [0.86934673 0.57377049 0.19858156]
#  [0.61306533 0.45901639 0.        ]]
# Training Labels (y): [0. 1. 1. 1. 1.]
# New Record (r): [0.85427136 0.52459016 0.26595745]
# Predicted Outcome: 1.0, Actual Outcome: 1.0
# 917
# Raw received data: {'Glucose': 0.4221105527638191, 'BloodPressure': 0.6065573770491803, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.5879397  0.72131148 0.1713948 ]
#  [0.52763819 0.68852459 0.        ]
#  [0.86934673 0.57377049 0.19858156]
#  [0.61306533 0.45901639 0.        ]
#  [0.85427136 0.52459016 0.26595745]]
# Training Labels (y): [1. 1. 1. 1. 1.]
# New Record (r): [0.42211055 0.60655738 0.        ]
# Predicted Outcome: 1.0, Actual Outcome: 0.0
# 916
# Raw received data: {'Glucose': 0.4824120603015075, 'BloodPressure': 0.5573770491803279, 'Insulin': 0.057919621749408984, 'Outcome': 0}
# Training Data (X): [[0.52763819 0.68852459 0.        ]
#  [0.86934673 0.57377049 0.19858156]
#  [0.61306533 0.45901639 0.        ]
#  [0.85427136 0.52459016 0.26595745]
#  [0.42211055 0.60655738 0.        ]]
# Training Labels (y): [1. 1. 1. 1. 0.]
# New Record (r): [0.48241206 0.55737705 0.05791962]
# Predicted Outcome: 1.0, Actual Outcome: 0.0
# 915
# Raw received data: {'Glucose': 0.628140703517588, 'BloodPressure': 0.49180327868852464, 'Insulin': 0.16548463356973994, 'Outcome': 0}
# Training Data (X): [[0.86934673 0.57377049 0.19858156]
#  [0.61306533 0.45901639 0.        ]
#  [0.85427136 0.52459016 0.26595745]
#  [0.42211055 0.60655738 0.        ]
#  [0.48241206 0.55737705 0.05791962]]
# Training Labels (y): [1. 1. 1. 0. 0.]
# New Record (r): [0.6281407  0.49180328 0.16548463]
# Predicted Outcome: 1.0, Actual Outcome: 0.0
# 914
# Raw received data: {'Glucose': 0.5025125628140703, 'BloodPressure': 0.5737704918032788, 'Insulin': 0.0591016548463357, 'Outcome': 0}
# Training Data (X): [[0.61306533 0.45901639 0.        ]
#  [0.85427136 0.52459016 0.26595745]
#  [0.42211055 0.60655738 0.        ]
#  [0.48241206 0.55737705 0.05791962]
#  [0.6281407  0.49180328 0.16548463]]
# Training Labels (y): [1. 1. 0. 0. 0.]
# New Record (r): [0.50251256 0.57377049 0.05910165]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 913
# Raw received data: {'Glucose': 0.46733668341708545, 'BloodPressure': 0.49180327868852464, 'Insulin': 0.10874704491725767, 'Outcome': 0}
# Training Data (X): [[0.85427136 0.52459016 0.26595745]
#  [0.42211055 0.60655738 0.        ]
#  [0.48241206 0.55737705 0.05791962]
#  [0.6281407  0.49180328 0.16548463]
#  [0.50251256 0.57377049 0.05910165]]
# Training Labels (y): [1. 0. 0. 0. 0.]
# New Record (r): [0.46733668 0.49180328 0.10874704]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 912
# Raw received data: {'Glucose': 0.6482412060301508, 'BloodPressure': 0.6557377049180328, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.42211055 0.60655738 0.        ]
#  [0.48241206 0.55737705 0.05791962]
#  [0.6281407  0.49180328 0.16548463]
#  [0.50251256 0.57377049 0.05910165]
#  [0.46733668 0.49180328 0.10874704]]
# Training Labels (y): [0. 0. 0. 0. 0.]
# New Record (r): [0.64824121 0.6557377  0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 911
# Raw received data: {'Glucose': 0.5276381909547738, 'BloodPressure': 0.5901639344262295, 'Insulin': 0.38416075650118203, 'Outcome': 0}
# Training Data (X): [[0.48241206 0.55737705 0.05791962]
#  [0.6281407  0.49180328 0.16548463]
#  [0.50251256 0.57377049 0.05910165]
#  [0.46733668 0.49180328 0.10874704]
#  [0.64824121 0.6557377  0.        ]]
# Training Labels (y): [0. 0. 0. 0. 0.]
# New Record (r): [0.52763819 0.59016393 0.38416076]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 910
# Raw received data: {'Glucose': 0.6432160804020101, 'BloodPressure': 0.639344262295082, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.6281407  0.49180328 0.16548463]
#  [0.50251256 0.57377049 0.05910165]
#  [0.46733668 0.49180328 0.10874704]
#  [0.64824121 0.6557377  0.        ]
#  [0.52763819 0.59016393 0.38416076]]
# Training Labels (y): [0. 0. 0. 0. 0.]
# New Record (r): [0.64321608 0.63934426 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 909
# Raw received data: {'Glucose': 0.5326633165829145, 'BloodPressure': 0.6721311475409837, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.50251256 0.57377049 0.05910165]
#  [0.46733668 0.49180328 0.10874704]
#  [0.64824121 0.6557377  0.        ]
#  [0.52763819 0.59016393 0.38416076]
#  [0.64321608 0.63934426 0.        ]]
# Training Labels (y): [0. 0. 0. 0. 0.]
# New Record (r): [0.53266332 0.67213115 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 908
# Raw received data: {'Glucose': 0.542713567839196, 'BloodPressure': 0.42622950819672134, 'Insulin': 0.07446808510638298, 'Outcome': 0}
# Training Data (X): [[0.46733668 0.49180328 0.10874704]
#  [0.64824121 0.6557377  0.        ]
#  [0.52763819 0.59016393 0.38416076]
#  [0.64321608 0.63934426 0.        ]
#  [0.53266332 0.67213115 0.        ]]
# Training Labels (y): [0. 0. 0. 0. 0.]
# New Record (r): [0.54271357 0.42622951 0.07446809]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 907
# Raw received data: {'Glucose': 0.542713567839196, 'BloodPressure': 0.5409836065573771, 'Insulin': 0.0, 'Outcome': 1}
# Training Data (X): [[0.64824121 0.6557377  0.        ]
#  [0.52763819 0.59016393 0.38416076]
#  [0.64321608 0.63934426 0.        ]
#  [0.53266332 0.67213115 0.        ]
#  [0.54271357 0.42622951 0.07446809]]
# Training Labels (y): [0. 0. 0. 0. 0.]
# New Record (r): [0.54271357 0.54098361 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 906
# Raw received data: {'Glucose': 0.7738693467336684, 'BloodPressure': 0.5081967213114754, 'Insulin': 0.33569739952718675, 'Outcome': 0}
# Training Data (X): [[0.52763819 0.59016393 0.38416076]
#  [0.64321608 0.63934426 0.        ]
#  [0.53266332 0.67213115 0.        ]
#  [0.54271357 0.42622951 0.07446809]
#  [0.54271357 0.54098361 0.        ]]
# Training Labels (y): [0. 0. 0. 0. 1.]
# New Record (r): [0.77386935 0.50819672 0.3356974 ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 905
# Raw received data: {'Glucose': 0.5125628140703518, 'BloodPressure': 0.6147540983606558, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.64321608 0.63934426 0.        ]
#  [0.53266332 0.67213115 0.        ]
#  [0.54271357 0.42622951 0.07446809]
#  [0.54271357 0.54098361 0.        ]
#  [0.77386935 0.50819672 0.3356974 ]]
# Training Labels (y): [0. 0. 0. 1. 0.]
# New Record (r): [0.51256281 0.6147541  0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 904
# Raw received data: {'Glucose': 0.2864321608040201, 'BloodPressure': 0.6557377049180328, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.53266332 0.67213115 0.        ]
#  [0.54271357 0.42622951 0.07446809]
#  [0.54271357 0.54098361 0.        ]
#  [0.77386935 0.50819672 0.3356974 ]
#  [0.51256281 0.6147541  0.        ]]
# Training Labels (y): [0. 0. 1. 0. 0.]
# New Record (r): [0.28643216 0.6557377  0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 903
# Raw received data: {'Glucose': 0.5326633165829145, 'BloodPressure': 0.5245901639344263, 'Insulin': 0.14066193853427897, 'Outcome': 0}
# Training Data (X): [[0.54271357 0.42622951 0.07446809]
#  [0.54271357 0.54098361 0.        ]
#  [0.77386935 0.50819672 0.3356974 ]
#  [0.51256281 0.6147541  0.        ]
#  [0.28643216 0.6557377  0.        ]]
# Training Labels (y): [0. 1. 0. 0. 0.]
# New Record (r): [0.53266332 0.52459016 0.14066194]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 902
# Raw received data: {'Glucose': 0.7386934673366834, 'BloodPressure': 0.639344262295082, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.54271357 0.54098361 0.        ]
#  [0.77386935 0.50819672 0.3356974 ]
#  [0.51256281 0.6147541  0.        ]
#  [0.28643216 0.6557377  0.        ]
#  [0.53266332 0.52459016 0.14066194]]
# Training Labels (y): [1. 0. 0. 0. 0.]
# New Record (r): [0.73869347 0.63934426 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 901
# Raw received data: {'Glucose': 0.45226130653266333, 'BloodPressure': 0.5737704918032788, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.77386935 0.50819672 0.3356974 ]
#  [0.51256281 0.6147541  0.        ]
#  [0.28643216 0.6557377  0.        ]
#  [0.53266332 0.52459016 0.14066194]
#  [0.73869347 0.63934426 0.        ]]
# Training Labels (y): [0. 0. 0. 0. 0.]
# New Record (r): [0.45226131 0.57377049 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 900
# ...
# Training Data (X): [[0.69849246 0.44262295 0.        ]
#  [0.59798995 0.40983607 0.20803783]
#  [0.73366834 0.62295082 0.22931442]
#  [0.92462312 0.69672131 0.        ]
#  [0.61306533 0.55737705 0.        ]]
# Training Labels (y): [1. 1. 0. 1. 0.]
# New Record (r): [0.82914573 0.73770492 0.80378251]
# Predicted Outcome: 1.0, Actual Outcome: 0.0
# 34
# Raw received data: {'Glucose': 0.6231155778894473, 'BloodPressure': 0.5737704918032788, 'Insulin': 0.47517730496453897, 'Outcome': 0}
# Training Data (X): [[0.59798995 0.40983607 0.20803783]
#  [0.73366834 0.62295082 0.22931442]
#  [0.92462312 0.69672131 0.        ]
#  [0.61306533 0.55737705 0.        ]
#  [0.82914573 0.73770492 0.80378251]]
# Training Labels (y): [1. 0. 1. 0. 0.]
# New Record (r): [0.62311558 0.57377049 0.4751773 ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 33
# Raw received data: {'Glucose': 0.5577889447236181, 'BloodPressure': 0.7049180327868853, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.73366834 0.62295082 0.22931442]
#  [0.92462312 0.69672131 0.        ]
#  [0.61306533 0.55737705 0.        ]
#  [0.82914573 0.73770492 0.80378251]
#  [0.62311558 0.57377049 0.4751773 ]]
# Training Labels (y): [0. 1. 0. 0. 0.]
# New Record (r): [0.55778894 0.70491803 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 32
# Raw received data: {'Glucose': 0.5326633165829145, 'BloodPressure': 0.42622950819672134, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.92462312 0.69672131 0.        ]
#  [0.61306533 0.55737705 0.        ]
#  [0.82914573 0.73770492 0.80378251]
#  [0.62311558 0.57377049 0.4751773 ]
#  [0.55778894 0.70491803 0.        ]]
# Training Labels (y): [1. 0. 0. 0. 0.]
# New Record (r): [0.53266332 0.42622951 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 31
# Raw received data: {'Glucose': 0.6482412060301508, 'BloodPressure': 0.6885245901639344, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.61306533 0.55737705 0.        ]
#  [0.82914573 0.73770492 0.80378251]
#  [0.62311558 0.57377049 0.4751773 ]
#  [0.55778894 0.70491803 0.        ]
#  [0.53266332 0.42622951 0.        ]]
# Training Labels (y): [0. 0. 0. 0. 0.]
# New Record (r): [0.64824121 0.68852459 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 30
# Raw received data: {'Glucose': 0.45226130653266333, 'BloodPressure': 0.6557377049180328, 'Insulin': 0.06501182033096926, 'Outcome': 0}
# Training Data (X): [[0.82914573 0.73770492 0.80378251]
#  [0.62311558 0.57377049 0.4751773 ]
#  [0.55778894 0.70491803 0.        ]
#  [0.53266332 0.42622951 0.        ]
#  [0.64824121 0.68852459 0.        ]]
# Training Labels (y): [0. 0. 0. 0. 0.]
# New Record (r): [0.45226131 0.6557377  0.06501182]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 29
# Raw received data: {'Glucose': 0.4321608040201005, 'BloodPressure': 0.5573770491803279, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.62311558 0.57377049 0.4751773 ]
#  [0.55778894 0.70491803 0.        ]
#  [0.53266332 0.42622951 0.        ]
#  [0.64824121 0.68852459 0.        ]
#  [0.45226131 0.6557377  0.06501182]]
# Training Labels (y): [0. 0. 0. 0. 0.]
# New Record (r): [0.4321608  0.55737705 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 28
# Raw received data: {'Glucose': 0.4623115577889447, 'BloodPressure': 0.5081967213114754, 'Insulin': 0.3049645390070922, 'Outcome': 1}
# Training Data (X): [[0.55778894 0.70491803 0.        ]
#  [0.53266332 0.42622951 0.        ]
#  [0.64824121 0.68852459 0.        ]
#  [0.45226131 0.6557377  0.06501182]
#  [0.4321608  0.55737705 0.        ]]
# Training Labels (y): [0. 0. 0. 0. 0.]
# New Record (r): [0.46231156 0.50819672 0.30496454]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 27
# Raw received data: {'Glucose': 0.5678391959798995, 'BloodPressure': 0.5245901639344263, 'Insulin': 0.0, 'Outcome': 1}
# Training Data (X): [[0.53266332 0.42622951 0.        ]
#  [0.64824121 0.68852459 0.        ]
#  [0.45226131 0.6557377  0.06501182]
#  [0.4321608  0.55737705 0.        ]
#  [0.46231156 0.50819672 0.30496454]]
# Training Labels (y): [0. 0. 0. 0. 1.]
# New Record (r): [0.5678392  0.52459016 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 26
# Raw received data: {'Glucose': 0.5577889447236181, 'BloodPressure': 0.45901639344262296, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.64824121 0.68852459 0.        ]
#  [0.45226131 0.6557377  0.06501182]
#  [0.4321608  0.55737705 0.        ]
#  [0.46231156 0.50819672 0.30496454]
#  [0.5678392  0.52459016 0.        ]]
# Training Labels (y): [0. 0. 0. 1. 1.]
# New Record (r): [0.55778894 0.45901639 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 25
# Raw received data: {'Glucose': 0.5728643216080402, 'BloodPressure': 0.5573770491803279, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.45226131 0.6557377  0.06501182]
#  [0.4321608  0.55737705 0.        ]
#  [0.46231156 0.50819672 0.30496454]
#  [0.5678392  0.52459016 0.        ]
#  [0.55778894 0.45901639 0.        ]]
# Training Labels (y): [0. 0. 1. 1. 0.]
# New Record (r): [0.57286432 0.55737705 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 24
# Raw received data: {'Glucose': 0.9698492462311558, 'BloodPressure': 0.4098360655737705, 'Insulin': 0.4432624113475177, 'Outcome': 0}
# Training Data (X): [[0.4321608  0.55737705 0.        ]
#  [0.46231156 0.50819672 0.30496454]
#  [0.5678392  0.52459016 0.        ]
#  [0.55778894 0.45901639 0.        ]
#  [0.57286432 0.55737705 0.        ]]
# Training Labels (y): [0. 1. 1. 0. 0.]
# New Record (r): [0.96984925 0.40983607 0.44326241]
# Predicted Outcome: 1.0, Actual Outcome: 0.0
# 23
# Raw received data: {'Glucose': 0.7788944723618091, 'BloodPressure': 0.6229508196721312, 'Insulin': 0.1773049645390071, 'Outcome': 1}
# Training Data (X): [[0.46231156 0.50819672 0.30496454]
#  [0.5678392  0.52459016 0.        ]
#  [0.55778894 0.45901639 0.        ]
#  [0.57286432 0.55737705 0.        ]
#  [0.96984925 0.40983607 0.44326241]]
# Training Labels (y): [1. 1. 0. 0. 0.]
# New Record (r): [0.77889447 0.62295082 0.17730496]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 22
# Raw received data: {'Glucose': 0.9597989949748744, 'BloodPressure': 0.5573770491803279, 'Insulin': 0.1536643026004728, 'Outcome': 0}
# Training Data (X): [[0.5678392  0.52459016 0.        ]
#  [0.55778894 0.45901639 0.        ]
#  [0.57286432 0.55737705 0.        ]
#  [0.96984925 0.40983607 0.44326241]
#  [0.77889447 0.62295082 0.17730496]]
# Training Labels (y): [1. 0. 0. 0. 1.]
# New Record (r): [0.95979899 0.55737705 0.1536643 ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 21
# Raw received data: {'Glucose': 0.7085427135678392, 'BloodPressure': 0.0, 'Insulin': 0.0, 'Outcome': 1}
# Training Data (X): [[0.55778894 0.45901639 0.        ]
#  [0.57286432 0.55737705 0.        ]
#  [0.96984925 0.40983607 0.44326241]
#  [0.77889447 0.62295082 0.17730496]
#  [0.95979899 0.55737705 0.1536643 ]]
# Training Labels (y): [0. 0. 0. 1. 0.]
# New Record (r): [0.70854271 0.         0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 20
# Raw received data: {'Glucose': 0.47738693467336685, 'BloodPressure': 0.5737704918032788, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.57286432 0.55737705 0.        ]
#  [0.96984925 0.40983607 0.44326241]
#  [0.77889447 0.62295082 0.17730496]
#  [0.95979899 0.55737705 0.1536643 ]
#  [0.70854271 0.         0.        ]]
# Training Labels (y): [0. 0. 1. 0. 1.]
# New Record (r): [0.47738693 0.57377049 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 19
# Raw received data: {'Glucose': 0.7135678391959799, 'BloodPressure': 0.6557377049180328, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.96984925 0.40983607 0.44326241]
#  [0.77889447 0.62295082 0.17730496]
#  [0.95979899 0.55737705 0.1536643 ]
#  [0.70854271 0.         0.        ]
#  [0.47738693 0.57377049 0.        ]]
# Training Labels (y): [0. 1. 0. 1. 0.]
# New Record (r): [0.71356784 0.6557377  0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 18
# Raw received data: {'Glucose': 0.6180904522613065, 'BloodPressure': 0.5081967213114754, 'Insulin': 0.0, 'Outcome': 1}
# Training Data (X): [[0.77889447 0.62295082 0.17730496]
#  [0.95979899 0.55737705 0.1536643 ]
#  [0.70854271 0.         0.        ]
#  [0.47738693 0.57377049 0.        ]
#  [0.71356784 0.6557377  0.        ]]
# Training Labels (y): [1. 0. 1. 0. 0.]
# New Record (r): [0.61809045 0.50819672 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 17
# Raw received data: {'Glucose': 0.4824120603015075, 'BloodPressure': 0.6065573770491803, 'Insulin': 0.07919621749408984, 'Outcome': 0}
# Training Data (X): [[0.95979899 0.55737705 0.1536643 ]
#  [0.70854271 0.         0.        ]
#  [0.47738693 0.57377049 0.        ]
#  [0.71356784 0.6557377  0.        ]
#  [0.61809045 0.50819672 0.        ]]
# Training Labels (y): [0. 1. 0. 0. 1.]
# New Record (r): [0.48241206 0.60655738 0.07919622]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 16
# Raw received data: {'Glucose': 0.6934673366834171, 'BloodPressure': 0.0, 'Insulin': 0.0, 'Outcome': 1}
# Training Data (X): [[0.70854271 0.         0.        ]
#  [0.47738693 0.57377049 0.        ]
#  [0.71356784 0.6557377  0.        ]
#  [0.61809045 0.50819672 0.        ]
#  [0.48241206 0.60655738 0.07919622]]
# Training Labels (y): [1. 0. 0. 1. 0.]
# New Record (r): [0.69346734 0.         0.        ]
# Predicted Outcome: 1.0, Actual Outcome: 1.0
# 15
# Raw received data: {'Glucose': 0.6432160804020101, 'BloodPressure': 0.5245901639344263, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.47738693 0.57377049 0.        ]
#  [0.71356784 0.6557377  0.        ]
#  [0.61809045 0.50819672 0.        ]
#  [0.48241206 0.60655738 0.07919622]
#  [0.69346734 0.         0.        ]]
# Training Labels (y): [0. 0. 1. 0. 1.]
# New Record (r): [0.64321608 0.52459016 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 14
# Raw received data: {'Glucose': 0.5125628140703518, 'BloodPressure': 0.42622950819672134, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.71356784 0.6557377  0.        ]
#  [0.61809045 0.50819672 0.        ]
#  [0.48241206 0.60655738 0.07919622]
#  [0.69346734 0.         0.        ]
#  [0.64321608 0.52459016 0.        ]]
# Training Labels (y): [0. 1. 0. 1. 0.]
# New Record (r): [0.51256281 0.42622951 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 13
# Raw received data: {'Glucose': 0.7336683417085427, 'BloodPressure': 0.0, 'Insulin': 0.0, 'Outcome': 1}
# Training Data (X): [[0.61809045 0.50819672 0.        ]
#  [0.48241206 0.60655738 0.07919622]
#  [0.69346734 0.         0.        ]
#  [0.64321608 0.52459016 0.        ]
#  [0.51256281 0.42622951 0.        ]]
# Training Labels (y): [1. 0. 1. 0. 0.]
# New Record (r): [0.73366834 0.         0.        ]
# Predicted Outcome: 1.0, Actual Outcome: 1.0
# 12
# Raw received data: {'Glucose': 0.507537688442211, 'BloodPressure': 0.7049180327868853, 'Insulin': 0.0, 'Outcome': 1}
# Training Data (X): [[0.48241206 0.60655738 0.07919622]
#  [0.69346734 0.         0.        ]
#  [0.64321608 0.52459016 0.        ]
#  [0.51256281 0.42622951 0.        ]
#  [0.73366834 0.         0.        ]]
# Training Labels (y): [0. 1. 0. 0. 1.]
# New Record (r): [0.50753769 0.70491803 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 11
# Raw received data: {'Glucose': 0.542713567839196, 'BloodPressure': 0.5081967213114754, 'Insulin': 0.06619385342789598, 'Outcome': 0}
# Training Data (X): [[0.69346734 0.         0.        ]
#  [0.64321608 0.52459016 0.        ]
#  [0.51256281 0.42622951 0.        ]
#  [0.73366834 0.         0.        ]
#  [0.50753769 0.70491803 0.        ]]
# Training Labels (y): [1. 0. 0. 1. 1.]
# New Record (r): [0.54271357 0.50819672 0.06619385]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 10
# Raw received data: {'Glucose': 0.6130653266331658, 'BloodPressure': 0.639344262295082, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.64321608 0.52459016 0.        ]
#  [0.51256281 0.42622951 0.        ]
#  [0.73366834 0.         0.        ]
#  [0.50753769 0.70491803 0.        ]
#  [0.54271357 0.50819672 0.06619385]]
# Training Labels (y): [0. 0. 1. 1. 0.]
# New Record (r): [0.61306533 0.63934426 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 9
# Raw received data: {'Glucose': 0.35678391959798994, 'BloodPressure': 0.639344262295082, 'Insulin': 0.05319148936170213, 'Outcome': 0}
# Training Data (X): [[0.51256281 0.42622951 0.        ]
#  [0.73366834 0.         0.        ]
#  [0.50753769 0.70491803 0.        ]
#  [0.54271357 0.50819672 0.06619385]
#  [0.61306533 0.63934426 0.        ]]
# Training Labels (y): [0. 1. 1. 0. 0.]
# New Record (r): [0.35678392 0.63934426 0.05319149]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 8
# Raw received data: {'Glucose': 0.5326633165829145, 'BloodPressure': 0.5737704918032788, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.73366834 0.         0.        ]
#  [0.50753769 0.70491803 0.        ]
#  [0.54271357 0.50819672 0.06619385]
#  [0.61306533 0.63934426 0.        ]
#  [0.35678392 0.63934426 0.05319149]]
# Training Labels (y): [1. 1. 0. 0. 0.]
# New Record (r): [0.53266332 0.57377049 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 7
# Raw received data: {'Glucose': 0.5025125628140703, 'BloodPressure': 0.5737704918032788, 'Insulin': 0.0673758865248227, 'Outcome': 0}
# Training Data (X): [[0.50753769 0.70491803 0.        ]
#  [0.54271357 0.50819672 0.06619385]
#  [0.61306533 0.63934426 0.        ]
#  [0.35678392 0.63934426 0.05319149]
#  [0.53266332 0.57377049 0.        ]]
# Training Labels (y): [1. 0. 0. 0. 0.]
# New Record (r): [0.50251256 0.57377049 0.06737589]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 6
# Raw received data: {'Glucose': 0.5326633165829145, 'BloodPressure': 0.49180327868852464, 'Insulin': 0.0, 'Outcome': 1}
# Training Data (X): [[0.54271357 0.50819672 0.06619385]
#  [0.61306533 0.63934426 0.        ]
#  [0.35678392 0.63934426 0.05319149]
#  [0.53266332 0.57377049 0.        ]
#  [0.50251256 0.57377049 0.06737589]]
# Training Labels (y): [0. 0. 0. 0. 0.]
# New Record (r): [0.53266332 0.49180328 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 5
# Raw received data: {'Glucose': 0.5226130653266332, 'BloodPressure': 0.5245901639344263, 'Insulin': 0.13711583924349882, 'Outcome': 0}
# Training Data (X): [[0.61306533 0.63934426 0.        ]
#  [0.35678392 0.63934426 0.05319149]
#  [0.53266332 0.57377049 0.        ]
#  [0.50251256 0.57377049 0.06737589]
#  [0.53266332 0.49180328 0.        ]]
# Training Labels (y): [0. 0. 0. 0. 1.]
# New Record (r): [0.52261307 0.52459016 0.13711584]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 4
# Raw received data: {'Glucose': 0.5728643216080402, 'BloodPressure': 0.6065573770491803, 'Insulin': 0.0, 'Outcome': 0}
# Training Data (X): [[0.35678392 0.63934426 0.05319149]
#  [0.53266332 0.57377049 0.        ]
#  [0.50251256 0.57377049 0.06737589]
#  [0.53266332 0.49180328 0.        ]
#  [0.52261307 0.52459016 0.13711584]]
# Training Labels (y): [0. 0. 0. 1. 0.]
# New Record (r): [0.57286432 0.60655738 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 3
# Raw received data: {'Glucose': 0.542713567839196, 'BloodPressure': 0.5081967213114754, 'Insulin': 0.32860520094562645, 'Outcome': 0}
# Training Data (X): [[0.53266332 0.57377049 0.        ]
#  [0.50251256 0.57377049 0.06737589]
#  [0.53266332 0.49180328 0.        ]
#  [0.52261307 0.52459016 0.13711584]
#  [0.57286432 0.60655738 0.        ]]
# Training Labels (y): [0. 0. 1. 0. 0.]
# New Record (r): [0.54271357 0.50819672 0.3286052 ]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 2
# Raw received data: {'Glucose': 0.7336683417085427, 'BloodPressure': 0.5737704918032788, 'Insulin': 0.0, 'Outcome': 1}
# Training Data (X): [[0.50251256 0.57377049 0.06737589]
#  [0.53266332 0.49180328 0.        ]
#  [0.52261307 0.52459016 0.13711584]
#  [0.57286432 0.60655738 0.        ]
#  [0.54271357 0.50819672 0.3286052 ]]
# Training Labels (y): [0. 1. 0. 0. 0.]
# New Record (r): [0.73366834 0.57377049 0.        ]
# Predicted Outcome: 0.0, Actual Outcome: 1.0
# 1
# Raw received data: {'Glucose': 0.6482412060301508, 'BloodPressure': 0.6229508196721312, 'Insulin': 0.1442080378250591, 'Outcome': 0}
# Training Data (X): [[0.53266332 0.49180328 0.        ]
#  [0.52261307 0.52459016 0.13711584]
#  [0.57286432 0.60655738 0.        ]
#  [0.54271357 0.50819672 0.3286052 ]
#  [0.73366834 0.57377049 0.        ]]
# Training Labels (y): [1. 0. 0. 0. 1.]
# New Record (r): [0.64824121 0.62295082 0.14420804]
# Predicted Outcome: 0.0, Actual Outcome: 0.0
# 0
# Final Result: 623 correct classifications out of 1000.

# %% [markdown]
# The first run the final Result was 623 correct classifications out of 1000.
# Which indicates the model is learning, but 62.3% is not much more reliable than random guessing
